# %%
import pandas as pd

df = pd.read_csv("globalAirQuality.csv")
#basic functions of dataframe that help to deal with files complex data
df.head()
df.tail()
df.sample()
df.info()
df.describe()
df.nunique()
df.columns
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    18000 non-null  object
#  1   country      18000 non-null  object
#  2   city         18000 non-null  object
#  3   latitude     18000 non-null  float64
#  4   longitude    18000 non-null  float64
#  5   pm25         18000 non-null  float64
#  6   pm10         18000 non-null  float64
#  7   no2          18000 non-null  float64
#  8   so2          18000 non-null  float64
#  9   o3           18000 non-null  float64
#  10  co           18000 non-null  float64
#  11  aqi          18000 non-null  int64
#  12  temperature  18000 non-null  float64
#  13  humidity     18000 non-null  float64
#  14  wind_speed   18000 non-null  float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 2.1+ MB
# (18000, 15)

# %%
df.loc[0:2]
df.iloc[0:2]
df.loc[0,["aqi","city"]]
df.loc[0:2,["city","aqi"]]
#for same work with iloc 
df.iloc[0:2,[1,2]]#pass columns index
df.at[0,"city"]
df.iat[0,2]
# Out:
# 'New York'

# %%
#filter the data with square brackets[]
df[df["city"]=="New York"]
df[(df["aqi"]>180) & (df["city"] == "Paris")]

df[df["aqi"]<50 ]["city"]
# Out:
# 22          New York
# 43          New York
# 252         New York
# 533      Los Angeles
# 807           London
#             ...
# 17624       Helsinki
# 17713         Zurich
# 17811         Zurich
# 17962         Zurich
# 17986         Zurich
# Name: city, Length: 158, dtype: object

# %%
# with query()

df.query("aqi < 30")
city_name = "New York"
df.query("city == @city_name")[["aqi","country"]]

#use single codes to compare string
df.query("city == 'Paris'")
# Out:
#                        timestamp country   city  latitude  longitude    pm25  \
# 1080  2025-11-04 18:25:17.554219      FR  Paris    48.857      2.352  32.613
# 1081  2025-11-04 19:25:17.554219      FR  Paris    48.857      2.352  76.137
# 1082  2025-11-04 20:25:17.554219      FR  Paris    48.857      2.352  58.671
# 1083  2025-11-04 21:25:17.554219      FR  Paris    48.857      2.352  33.720
# 1084  2025-11-04 22:25:17.554219      FR  Paris    48.857      2.352  38.569
# ...                          ...     ...    ...       ...        ...     ...
# 1435  2025-11-19 13:25:17.554219      FR  Paris    48.857      2.352  38.255
# 1436  2025-11-19 14:25:17.554219      FR  Paris    48.857      2.352  46.705
# 1437  2025-11-19 15:25:17.554219      FR  Paris    48.857      2.352  56.741
# 1438  2025-11-19 16:25:17.554219      FR  Paris    48.857      2.352  35.457
# 1439  2025-11-19 17:25:17.554219      FR  Paris    48.857      2.352  34.836
#
# ...

# %%
df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...
